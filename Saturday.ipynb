# %%
import pandas as pd
import matplotlib as plt

# %%
Plastic_df = pd.read_excel("dataset/Plastic Data.xlsx")
Plastic_df.head()
# Out:
#    ID  Reference  Continent  Latitude (N)  Longitude €  Distance_land (miles)  \
# 0   1           1      Asia          33.0       122.21                   0.07
# 1   2           1      Asia          34.0       121.24                   0.06
# 2   3           1      Asia          36.0       121.00                   0.02
# 3   4           1      Asia          33.0       123.00                   0.10
# 4   5           1      Asia          35.0       121.00                   0.09
#
#         Habitat_Type  Water_Depth (m)  \
# 0  Continental_shelf             12.0
# 1  Continental_shelf             19.0
# 2  Continental_shelf             20.0
# 3  Continental_shelf             29.0
# 4  Continental_shelf             36.0
#
#    Mean Population in 110 km radius (no. people km-2)  Sampling_date  ...  \
# 0                                           0.000000          2017.0  ...
# 1                                         180.813815          2017.0  ...
# 2                                        1086.828963          2017.0  ...
# 3                                           0.000000          2017.0  ...
# 4                                         988.463074          2017.0  ...
#
#   Abundance_fibers (n kg-1)  Abundance_Non-fibrous (n kg-1)  \
# 0                    509.60                            50.4
# 1                   2841.60                           118.4
# 2                   3513.60                           146.4
# 3                   1534.95                          360.05
# 4                   1731.73                          171.27
#
#    Estimated_proportion  Estimated_Fibers (n kg-1)  \
# 0                  0.91                     509.60
# 1                  0.96                    2841.60
# 2                  0.96                    3513.60
# 3                  0.81                    1534.95
# 4                  0.91                    1731.73
#
#   Estimated_Non-fibrous (n kg-1)  Corrected_Fibers (n kg-1)  \
# 0                          50.40                2817.023270
# 1                         118.40               15708.110916
# 2                         146.40               19422.866876
# 3                         360.05                8485.066459
# 4                         171.27                9572.848718
#
#   Corrected_Non-Fibrous (n kg-1) Corrected_Fibers (n cm-3)  \
# 0                     278.606697                  1.719439
# 1                     654.504622                  9.587829
# 2                     809.286120                 11.855221
# 3                    1990.324231                  5.179067
# 4                     946.765258                  5.843022
#
#   Corrected_Non-Fibrous (n cm-3)  Sediment_accretion (cm y-1)
# 0                       0.170054                     0.131824
# 1                       0.399493                     0.130903
# 2                       0.493968                     0.130772
# 3                       1.214843                     0.129598
# 4                       0.577881                     0.128692
#
# [5 rows x 43 columns]

# %%
References_df = pd.read_excel("dataset/Plastic Data.xlsx", sheet_name = 3)
References_df.head()
# Out:
#    Reference  Central size (mm)  Weight (mg)
# 0          9              3.000     0.800000
# 1         28              3.555    47.930556
# 2         28              3.555    25.280000
# 3         28              3.555    24.000000
# 4         28              3.555    26.705882

# %%
Plastic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1649 entries, 0 to 1648
# Data columns (total 43 columns):
#  #   Column                                              Dtype
# ---  ------                                              -----
#  0   ID                                                  int64
#  1   Reference                                           int64
#  2   Continent                                           object
#  3   Latitude (N)                                        float64
#  4   Longitude €                                         float64
#  5   Distance_land (miles)                               float64
#  6   Habitat_Type                                        object
#  7   Water_Depth (m)                                     float64
#  8   Mean Population in 110 km radius (no. people km-2)  float64
#  9   Sampling_date                                       float64
#  10  Sampling_method                                     object
#  11  Lower_size_limit (um)                               float64
#  12  Correction_factor_size                              float64
#  13  Upper_size_limit (mm)                               float64
#  14  Density_separation_method                           object
#  15  Recovery_density_separation (%)                     float64
#  16  Screening                                           object
#  17  FTIR_Raman                                          object
#  18  Mitigation_against_contamination                    object
#  19  Depth_min (cm)                                      float64
#  20  Depth_max (cm)                                      float64
#  21  Central_depth (cm)                                  float64
#  22  Thickness (cm)                                      float64
#  23  Dry_bulk_density_DBD (g cm-3)                       float64
#  24  OriginalSource_DBD                                  object
#  25  DataSource_DBD                                      object
#  26  Number_of_samples                                   float64
#  27  Plastic_abundance                                   object
#  28  (+/-)                                               object
#  29  Error_type                                          object
#  30  Unit                                                object
#  31  Plastic_abundance_converted (n kg-1)                float64
#  32  Proportion_fibers                                   float64
#  33  Abundance_fibers (n kg-1)                           float64
#  34  Abundance_Non-fibrous (n kg-1)                      object
#  35  Estimated_proportion                                float64
#  36  Estimated_Fibers (n kg-1)                           float64
#  37  Estimated_Non-fibrous (n kg-1)                      float64
#  38  Corrected_Fibers (n kg-1)                           float64
#  39  Corrected_Non-Fibrous (n kg-1)                      float64
#  40  Corrected_Fibers (n cm-3)                           float64
#  41  Corrected_Non-Fibrous (n cm-3)                      float64
#  42  Sediment_accretion (cm y-1)                         float64
# dtypes: float64(27), int64(2), object(14)
# memory usage: 554.1+ KB

# %%
Plastic_df["Habitat_Type"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
Plastic_df.plot(kind="scatter", x = "Abundance_fibers (n kg-1)" , y = "Estimated_Fibers (n kg-1)")
# Out:
# <Axes: xlabel='Abundance_fibers (n kg-1)', ylabel='Estimated_Fibers (n kg-1)'>
